# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import itertools

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,association_rules

# %%
#Leemos CSV1 
df1=pd.read_csv('Csvs/WideReleasesCount.csv')
#Quitamos columnas undifined Y COLUMNAS QUE NO NOS FUNCIONARAN
df1=df1.drop(['Unnamed: 9'],axis=1)
df1=df1.drop(['YEAR'],axis=1)
df1=df1.drop(['TOTAL OTHER STUDIOS'],axis=1)
df1=df1.drop(['TOTAL MAJOR 6'],axis=1)
df1
# Out:
#     WARNER BROS  WALT DISNEY  20TH CENTURY FOX  PARAMOUNT PICTURES  \
# 0            17            7                 0                   4
# 1             5            3                 1                   3
# 2            18           10                11                   9
# 3            19           10                11                  10
# 4            18            8                14                  10
# 5            17           12                16                  12
# 6            22           11                18                   9
# 7            17           12                17                  10
# 8            17            8                15                   8
# 9            16           11                15                  13
# 10           20           13                15                  13
# 11           20           12                18                  12
# 12           25           14                20                  10
# 13           19           11                22                  14
# 14           30           13                17                  16
# 15           26           17                25                  13
# 16           20           20                19                  12
# 17           27           25                18                  14
# 18           28           19                13                  14
# 19           32           23                15                  16
# 20           30           16                16                  14
# 21           29           22                13                  12
# 22           27           20                15                  13
# 23           27           21                11                  11
# 24           31           22                12                  16
# 25           31           23                13                  16
# 26           27           22                11                  12
#
#     SONY PICTURES  UNIVERSAL
# 0              16         17
# 1               9         13
# 2              18         21
# 3              16         20
# 4              16         15
# 5              16         22
# 6              13         20
# 7              17         15
# 8              14         16
# 9              18         17
# 10             21         19
# 11             17         17
# 12             21         21
# 13             19         19
# 14             22         20
# 15             26         21
# 16             19         17
# 17             15         14
# 18             19         13
# 19             20         13
# 20             17         10
# 21             15         13
# 22             22         16
# 23             20         16
# 24             22         11
# 25             24         13
# 26             20         17

# %%
#Pondremos 1 si es que cumple con sacar mas de 10 peliculas y 0 en contrario para conseguir una tabla binaria
df1['WARNER BROS']=np.where(df1['WARNER BROS']<=15,0,1)
df1['WALT DISNEY']=np.where(df1['WALT DISNEY']<=15,0,1)
df1['20TH CENTURY FOX']=np.where(df1['20TH CENTURY FOX']<=15,0,1)
df1['PARAMOUNT PICTURES']=np.where(df1['PARAMOUNT PICTURES']<=15,0,1)
df1['SONY PICTURES']=np.where(df1['SONY PICTURES']<=15,0,1)
df1['UNIVERSAL']=np.where(df1['UNIVERSAL']<=15,0,1)
df1
# Out:
#     WARNER BROS  WALT DISNEY  20TH CENTURY FOX  PARAMOUNT PICTURES  \
# 0             1            0                 0                   0
# 1             0            0                 0                   0
# 2             1            0                 0                   0
# 3             1            0                 0                   0
# 4             1            0                 0                   0
# 5             1            0                 1                   0
# 6             1            0                 1                   0
# 7             1            0                 1                   0
# 8             1            0                 0                   0
# 9             1            0                 0                   0
# 10            1            0                 0                   0
# 11            1            0                 1                   0
# 12            1            0                 1                   0
# 13            1            0                 1                   0
# 14            1            0                 1                   1
# 15            1            1                 1                   0
# 16            1            1                 1                   0
# 17            1            1                 1                   0
# 18            1            1                 0                   0
# 19            1            1                 0                   1
# 20            1            1                 1                   0
# 21            1            1                 0                   0
# 22            1            1                 0                   0
# 23            1            1                 0                   0
# 24            1            1                 0                   1
# 25            1            1                 0                   1
# 26            1            1                 0                   0
#
#     SONY PICTURES  UNIVERSAL
# 0               1          1
# 1               0          0
# 2               1          1
# 3               1          1
# 4               1          0
# 5               1          1
# 6               0          1
# 7               1          0
# 8               0          1
# 9               1          1
# 10              1          1
# 11              1          1
# 12              1          1
# 13              1          1
# 14              1          1
# 15              1          1
# 16              1          1
# 17              0          0
# 18              1          0
# 19              1          0
# 20              1          0
# 21              0          0
# 22              1          1
# 23              1          1
# 24              1          0
# 25              1          0
# 26              1          1

# %%
df1.sum()
# Out:
# WARNER BROS           26
# WALT DISNEY           12
# 20TH CENTURY FOX      11
# PARAMOUNT PICTURES     4
# SONY PICTURES         22
# UNIVERSAL             17
# dtype: int64

# %%
#dividir todos los elemntos con el numero de la fila podemos encotnrar el valor de Sporte

first =pd.DataFrame(df1.sum()/df1.shape[0],columns=["Suport"]).sort_values("Suport",ascending=False)
first
# Out:
#                       Suport
# WARNER BROS         0.962963
# SONY PICTURES       0.814815
# UNIVERSAL           0.629630
# WALT DISNEY         0.444444
# 20TH CENTURY FOX    0.407407
# PARAMOUNT PICTURES  0.148148

# %%
#Eliminacion por valor de soporte
#pendiente de calcular
first[first.Suport >= .41]
# Out:
#                  Suport
# WARNER BROS    0.962963
# SONY PICTURES  0.814815
# UNIVERSAL      0.629630
# WALT DISNEY    0.444444

# %%
#Realizar productos de pares
second = list(itertools.combinations(first.index,2))
second = [list(i)for i in second]
second[:10]
# Out:
# [['WARNER BROS', 'SONY PICTURES'],
#  ['WARNER BROS', 'UNIVERSAL'],
#  ['WARNER BROS', 'WALT DISNEY'],
#  ['WARNER BROS', '20TH CENTURY FOX'],
#  ['WARNER BROS', 'PARAMOUNT PICTURES'],
#  ['SONY PICTURES', 'UNIVERSAL'],
#  ['SONY PICTURES', 'WALT DISNEY'],
#  ['SONY PICTURES', '20TH CENTURY FOX'],
#  ['SONY PICTURES', 'PARAMOUNT PICTURES'],
#  ['UNIVERSAL', 'WALT DISNEY']]

# %%
#Encontrar valores de apoyo
value=[]
for i in range(0,len(second)):
    temp = df1.T.loc[second[i]].sum()
    temp = len(temp[temp == df1.T.loc[second[i]].shape[0]])/df1.shape[0]
    value.append(temp)
#Creamos un data frame
secondIteration = pd.DataFrame(value,columns=["Suport"])
secondIteration["index"]=[tuple(i) for i in second]
secondIteration["length"]=secondIteration["index"].apply(lambda x:len(x))
secondIteration = secondIteration.set_index("index").sort_values("Suport",ascending = False)
#Elimamos el valor de soporte
secondIteration= secondIteration[secondIteration.Suport > 0.1]
secondIteration
# Out:
#                                        Suport  length
# index
# (WARNER BROS, SONY PICTURES)         0.814815       2
# (WARNER BROS, UNIVERSAL)             0.629630       2
# (SONY PICTURES, UNIVERSAL)           0.555556       2
# (WARNER BROS, WALT DISNEY)           0.444444       2
# (WARNER BROS, 20TH CENTURY FOX)      0.407407       2
# (SONY PICTURES, WALT DISNEY)         0.370370       2
# (SONY PICTURES, 20TH CENTURY FOX)    0.333333       2
# (UNIVERSAL, 20TH CENTURY FOX)        0.296296       2
# (UNIVERSAL, WALT DISNEY)             0.185185       2
# (WARNER BROS, PARAMOUNT PICTURES)    0.148148       2
# (SONY PICTURES, PARAMOUNT PICTURES)  0.148148       2
# (WALT DISNEY, 20TH CENTURY FOX)      0.148148       2
# (WALT DISNEY, PARAMOUNT PICTURES)    0.111111       2

# %%
def ar_iterations(data,num_iter=1,support_value = 0.1,iterationIndex =None):
    
    #Siguientes interaciones
    def ar_calculation(iterationIndex = iterationIndex):
        #Calcular el valor de soporte
        value = []
        for i in range(0,len(iterationIndex)):
            result =data.T.loc[iterationIndex[i]].sum()
            result =len(result[result== data.T.loc[iterationIndex[i]].shape[0]])/data.shape[0]
            value.append(result)
        #Bind results
        result=pd.DataFrame(value,columns=["Suport"])
        result["index"]=[tuple(i) for i in iterationIndex]
        result["length"]= result ["index"].apply(lambda x:len(x))
        result = result.set_index("index").sort_values("Suport",ascending=False)
        #Eliminacion de valor de soporte
        result = result[result.Suport > support_value]
        return result
    
    #Primer iteracion
    first = pd.DataFrame(df1.T.sum(axis=1)/df1.shape[0],columns=["Suport"]).sort_values("Suport",ascending= False)
    first = first[first.Suport >support_value]
    first["length"]=1
    
    if num_iter == 1 :
        res = first.copy()
    #Segunda
    elif num_iter  == 2:
        
        second = list(itertools.combinations(first.index,2))
        second = [list(i) for i in second]
        res =ar_calculation(second)
    
    else:
        nth = list(itertools.combinations(set(list(itertools.chain(*iterationIndex))), num_iter))
        nth=[list(i)for i in nth]
        res=ar_calculation(nth)
    
    return res

# %%
iteration1=ar_iterations(df1,num_iter=1,support_value=0.1)
iteration1
# Out:
#                       Suport  length
# WARNER BROS         0.962963       1
# SONY PICTURES       0.814815       1
# UNIVERSAL           0.629630       1
# WALT DISNEY         0.444444       1
# 20TH CENTURY FOX    0.407407       1
# PARAMOUNT PICTURES  0.148148       1

# %%
iteration2=ar_iterations(df1,num_iter=2,support_value=0.1)
iteration2
# Out:
#                                        Suport  length
# index
# (WARNER BROS, SONY PICTURES)         0.814815       2
# (WARNER BROS, UNIVERSAL)             0.629630       2
# (SONY PICTURES, UNIVERSAL)           0.555556       2
# (WARNER BROS, WALT DISNEY)           0.444444       2
# (WARNER BROS, 20TH CENTURY FOX)      0.407407       2
# (SONY PICTURES, WALT DISNEY)         0.370370       2
# (SONY PICTURES, 20TH CENTURY FOX)    0.333333       2
# (UNIVERSAL, 20TH CENTURY FOX)        0.296296       2
# (UNIVERSAL, WALT DISNEY)             0.185185       2
# (WARNER BROS, PARAMOUNT PICTURES)    0.148148       2
# (SONY PICTURES, PARAMOUNT PICTURES)  0.148148       2
# (WALT DISNEY, 20TH CENTURY FOX)      0.148148       2
# (WALT DISNEY, PARAMOUNT PICTURES)    0.111111       2

# %%
iteration3=ar_iterations(df1,num_iter=3,support_value=0.1,iterationIndex=iteration2.index)
iteration3
# Out:
#                                                     Suport  length
# index
# (SONY PICTURES, WARNER BROS, UNIVERSAL)           0.555556       3
# (WALT DISNEY, SONY PICTURES, WARNER BROS)         0.370370       3
# (20TH CENTURY FOX, SONY PICTURES, WARNER BROS)    0.333333       3
# (20TH CENTURY FOX, WARNER BROS, UNIVERSAL)        0.296296       3
# (20TH CENTURY FOX, SONY PICTURES, UNIVERSAL)      0.259259       3
# (WALT DISNEY, SONY PICTURES, UNIVERSAL)           0.185185       3
# (WALT DISNEY, WARNER BROS, UNIVERSAL)             0.185185       3
# (WALT DISNEY, 20TH CENTURY FOX, WARNER BROS)      0.148148       3
# (PARAMOUNT PICTURES, SONY PICTURES, WARNER BROS)  0.148148       3
# (WALT DISNEY, PARAMOUNT PICTURES, SONY PICTURES)  0.111111       3
# (WALT DISNEY, PARAMOUNT PICTURES, WARNER BROS)    0.111111       3
# (WALT DISNEY, 20TH CENTURY FOX, SONY PICTURES)    0.111111       3

# %%
iteration4=ar_iterations(df1,num_iter=4,support_value=0.1,iterationIndex=iteration3.index)
iteration4
# Out:
#                                                       Suport  length
# index
# (20TH CENTURY FOX, SONY PICTURES, WARNER BROS, ...  0.259259       4
# (WALT DISNEY, SONY PICTURES, WARNER BROS, UNIVE...  0.185185       4
# (WALT DISNEY, 20TH CENTURY FOX, SONY PICTURES, ...  0.111111       4
# (WALT DISNEY, PARAMOUNT PICTURES, SONY PICTURES...  0.111111       4

# %%
#Apriori
freq_items =apriori(df1,min_support= 0.36,use_colnames = True)
freq_items.sort_values("support",ascending =False)
# Out:
#      support                                   itemsets
# 0   0.962963                              (WARNER BROS)
# 3   0.814815                            (SONY PICTURES)
# 7   0.814815               (SONY PICTURES, WARNER BROS)
# 4   0.629630                                (UNIVERSAL)
# 8   0.629630                   (WARNER BROS, UNIVERSAL)
# 10  0.555556                 (SONY PICTURES, UNIVERSAL)
# 12  0.555556    (SONY PICTURES, WARNER BROS, UNIVERSAL)
# 1   0.444444                              (WALT DISNEY)
# 5   0.444444                 (WARNER BROS, WALT DISNEY)
# 2   0.407407                         (20TH CENTURY FOX)
# 6   0.407407            (20TH CENTURY FOX, WARNER BROS)
# 9   0.370370               (SONY PICTURES, WALT DISNEY)
# 11  0.370370  (SONY PICTURES, WARNER BROS, WALT DISNEY)

# %%
df_ar = association_rules(freq_items,metric="confidence",min_threshold = 0.60)
df_ar
# Out:
#                      antecedents                   consequents  \
# 0                  (WALT DISNEY)                 (WARNER BROS)
# 1             (20TH CENTURY FOX)                 (WARNER BROS)
# 2                (SONY PICTURES)                 (WARNER BROS)
# 3                  (WARNER BROS)               (SONY PICTURES)
# 4                  (WARNER BROS)                   (UNIVERSAL)
# 5                    (UNIVERSAL)                 (WARNER BROS)
# 6                  (WALT DISNEY)               (SONY PICTURES)
# 7                (SONY PICTURES)                   (UNIVERSAL)
# 8                    (UNIVERSAL)               (SONY PICTURES)
# 9   (SONY PICTURES, WALT DISNEY)                 (WARNER BROS)
# 10    (WARNER BROS, WALT DISNEY)               (SONY PICTURES)
# 11                 (WALT DISNEY)  (SONY PICTURES, WARNER BROS)
# 12  (SONY PICTURES, WARNER BROS)                   (UNIVERSAL)
# 13    (SONY PICTURES, UNIVERSAL)                 (WARNER BROS)
# 14      (WARNER BROS, UNIVERSAL)               (SONY PICTURES)
# 15               (SONY PICTURES)      (WARNER BROS, UNIVERSAL)
# 16                   (UNIVERSAL)  (SONY PICTURES, WARNER BROS)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.444444            0.962963  0.444444    1.000000  1.038462
# 1             0.407407            0.962963  0.407407    1.000000  1.038462
# 2             0.814815            0.962963  0.814815    1.000000  1.038462
# 3             0.962963            0.814815  0.814815    0.846154  1.038462
# 4             0.962963            0.629630  0.629630    0.653846  1.038462
# 5             0.629630            0.962963  0.629630    1.000000  1.038462
# 6             0.444444            0.814815  0.370370    0.833333  1.022727
# 7             0.814815            0.629630  0.555556    0.681818  1.082888
# 8             0.629630            0.814815  0.555556    0.882353  1.082888
# 9             0.370370            0.962963  0.370370    1.000000  1.038462
# 10            0.444444            0.814815  0.370370    0.833333  1.022727
# 11            0.444444            0.814815  0.370370    0.833333  1.022727
# 12            0.814815            0.629630  0.555556    0.681818  1.082888
# 13            0.555556            0.962963  0.555556    1.000000  1.038462
# 14            0.629630            0.814815  0.555556    0.882353  1.082888
# 15            0.814815            0.629630  0.555556    0.681818  1.082888
# 16            0.629630            0.814815  0.555556    0.882353  1.082888
#
#     leverage  conviction
# 0   0.016461         inf
# 1   0.015089         inf
# 2   0.030178         inf
# 3   0.030178    1.203704
# 4   0.023320    1.069959
# 5   0.023320         inf
# 6   0.008230    1.111111
# 7   0.042524    1.164021
# 8   0.042524    1.574074
# 9   0.013717         inf
# 10  0.008230    1.111111
# 11  0.008230    1.111111
# 12  0.042524    1.164021
# 13  0.020576         inf
# 14  0.042524    1.574074
# 15  0.042524    1.164021
# 16  0.042524    1.574074
